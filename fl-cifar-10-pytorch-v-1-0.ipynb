# %%
import torch
import torchvision
import copy
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision import datasets
import numpy as np

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(128 * 4 * 4, 256)
        self.fc2 = nn.Linear(256, 10)
        
    def forward(self, xb):
        xb = self.pool(F.relu(self.conv1(xb)))
        xb = self.pool(F.relu(self.conv2(xb)))
        xb = self.pool(F.relu(self.conv3(xb)))
        xb = xb.view(-1, 128 * 4 * 4)  # Flatten the tensor
        xb = F.relu(self.fc1(xb))
        xb = self.fc2(xb)
        return xb

# %%
def load_datasets():
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    
    train_dataset = datasets.CIFAR10(root='data/', train=True, transform=transform, download=True)
    test_dataset = datasets.CIFAR10(root='data/', train=False, transform=transform, download=True)
    
    return train_dataset, test_dataset
# Split dataset among clients
def split_data(train_dataset, num_clients):
    length = len(train_dataset) // num_clients
    client_datasets = random_split(train_dataset, [length]*num_clients)
    return client_datasets

# %%
def client_update(client_model, optimizer, train_loader, epochs=1):
    """Train the client model on the local dataset and return loss and accuracy."""
    client_model.train()
    criterion = nn.CrossEntropyLoss()
    total_loss = 0
    correct = 0
    total = 0
    
    for epoch in range(epochs):
        for images, labels in train_loader:
            optimizer.zero_grad()
            output = client_model(images)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            _, predicted = torch.max(output.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    avg_loss = total_loss / len(train_loader)
    accuracy = 100 * correct / total
    
    return client_model.state_dict(), avg_loss, accuracy

# %%
def server_aggregate(global_model, client_weights):
    """Aggregate the client models into the global model."""
    global_dict = global_model.state_dict()
    
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_weights[i][k].float() for i in range(len(client_weights))], 0).mean(0)
    
    global_model.load_state_dict(global_dict)
    return global_model

# %%
def federated_learning(train_dataset, num_clients=5, num_rounds=5, epochs=1):
    # Initialize global model
    global_model = SimpleCNN()
    
    # Split the dataset between clients
    client_datasets = split_data(train_dataset, num_clients)
    
    # Create data loaders for each client
    client_loaders = [DataLoader(client_datasets[i], batch_size=32, shuffle=True) for i in range(num_clients)]
    
    for round in range(num_rounds):
        print(f"Round {round+1}/{num_rounds}")
        
        client_weights = []
        client_losses = []
        client_accuracies = []
        
        # Train each client model
        for client_idx in range(num_clients):
            client_model = copy.deepcopy(global_model)
            optimizer = optim.SGD(client_model.parameters(), lr=0.01)
            
            # Update client model and get loss and accuracy
            client_weight, client_loss, client_accuracy = client_update(client_model, optimizer, client_loaders[client_idx], epochs)
            client_weights.append(client_weight)
            client_losses.append(client_loss)
            client_accuracies.append(client_accuracy)
        
        # Aggregate client models
        global_model = server_aggregate(global_model, client_weights)
        
        # Calculate and print the average loss and accuracy for the round
        avg_loss = np.mean(client_losses)
        avg_accuracy = np.mean(client_accuracies)
        
        print(f"Average Loss: {avg_loss:.4f}, Average Accuracy: {avg_accuracy:.2f}%")
    
    return global_model

# %%
def test(global_model, test_loader):
    global_model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            outputs = global_model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()

    print(f'Test Accuracy: {100 * correct / total:.2f}%')

# %%
if __name__ == "__main__":
    # Load datasets
    train_dataset, test_dataset = load_datasets()
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Perform federated learning
    global_model = federated_learning(train_dataset, num_clients=5, num_rounds=100, epochs=1)
    
    # Test the global model
    test(global_model, test_loader)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Round 1/100
# Average Loss: 2.2960, Average Accuracy: 11.77%
# Round 2/100
# Average Loss: 2.2387, Average Accuracy: 19.85%
# Round 3/100
# Average Loss: 2.0674, Average Accuracy: 25.95%
# Round 4/100
# Average Loss: 1.9178, Average Accuracy: 31.07%
# Round 5/100
# Average Loss: 1.8060, Average Accuracy: 34.72%
# Round 6/100
# Average Loss: 1.7175, Average Accuracy: 38.05%
# Round 7/100
# Average Loss: 1.6420, Average Accuracy: 40.54%
# Round 8/100
# Average Loss: 1.5799, Average Accuracy: 42.90%
# Round 9/100
# Average Loss: 1.5266, Average Accuracy: 44.57%
# Round 10/100
# Average Loss: 1.4843, Average Accuracy: 46.39%
# Round 11/100
# Average Loss: 1.4510, Average Accuracy: 47.56%
# Round 12/100
# Average Loss: 1.4208, Average Accuracy: 48.87%
# Round 13/100
# Average Loss: 1.3900, Average Accuracy: 50.08%
# Round 14/100
# Average Loss: 1.3624, Average Accuracy: 50.95%
# Round 15/100
# Average Loss: 1.3357, Average Accuracy: 52.14%
# Round 16/100
# Average Loss: 1.3092, Average Accuracy: 53.09%
# Round 17/100
# Average Loss: 1.2840, Average Accuracy: 53.93%
# Round 18/100
# Average Loss: 1.2593, Average Accuracy: 55.22%
# Round 19/100
# Average Loss: 1.2324, Average Accuracy: 56.14%
# Round 20/100
# Average Loss: 1.2122, Average Accuracy: 56.79%
# Round 21/100
# Average Loss: 1.1878, Average Accuracy: 57.89%
# Round 22/100
# Average Loss: 1.1668, Average Accuracy: 58.53%
# Round 23/100
# Average Loss: 1.1422, Average Accuracy: 59.59%
# Round 24/100
# Average Loss: 1.1248, Average Accuracy: 60.11%
# Round 25/100
# Average Loss: 1.1047, Average Accuracy: 61.03%
# Round 26/100
# Average Loss: 1.0812, Average Accuracy: 61.82%
# Round 27/100
# Average Loss: 1.0643, Average Accuracy: 62.46%
# Round 28/100
# Average Loss: 1.0470, Average Accuracy: 63.15%
# Round 29/100
# Average Loss: 1.0259, Average Accuracy: 63.81%
# Round 30/100
# Average Loss: 1.0090, Average Accuracy: 64.38%
# Round 31/100
# Average Loss: 0.9910, Average Accuracy: 65.25%
# Round 32/100
# Average Loss: 0.9740, Average Accuracy: 65.63%
# Round 33/100
# Average Loss: 0.9580, Average Accuracy: 66.17%
# Round 34/100
# Average Loss: 0.9397, Average Accuracy: 67.08%
# Round 35/100
# Average Loss: 0.9252, Average Accuracy: 67.49%
# Round 36/100
# Average Loss: 0.9096, Average Accuracy: 68.12%
# Round 37/100
# Average Loss: 0.8913, Average Accuracy: 68.67%
# Round 38/100
# Average Loss: 0.8764, Average Accuracy: 69.39%
# Round 39/100
# Average Loss: 0.8612, Average Accuracy: 69.81%
# Round 40/100
# Average Loss: 0.8456, Average Accuracy: 70.29%
# Round 41/100
# Average Loss: 0.8316, Average Accuracy: 71.00%
# Round 42/100
# Average Loss: 0.8202, Average Accuracy: 71.16%
# Round 43/100
# Average Loss: 0.8046, Average Accuracy: 71.98%
# Round 44/100
# Average Loss: 0.7901, Average Accuracy: 72.53%
# Round 45/100
# Average Loss: 0.7765, Average Accuracy: 72.79%
# Round 46/100
# Average Loss: 0.7636, Average Accuracy: 73.50%
# Round 47/100
# Average Loss: 0.7504, Average Accuracy: 73.94%
# Round 48/100
# Average Loss: 0.7386, Average Accuracy: 74.22%
# Round 49/100
# Average Loss: 0.7260, Average Accuracy: 74.48%
# Round 50/100
# Average Loss: 0.7119, Average Accuracy: 75.27%
# Round 51/100
# Average Loss: 0.6986, Average Accuracy: 75.69%
# Round 52/100
# Average Loss: 0.6899, Average Accuracy: 75.85%
# Round 53/100
# Average Loss: 0.6770, Average Accuracy: 76.27%
# Round 54/100
# Average Loss: 0.6641, Average Accuracy: 76.88%
# Round 55/100
# Average Loss: 0.6532, Average Accuracy: 77.23%
# Round 56/100
# Average Loss: 0.6405, Average Accuracy: 77.73%
# Round 57/100
# Average Loss: 0.6299, Average Accuracy: 78.22%
# Round 58/100
# Average Loss: 0.6168, Average Accuracy: 78.48%
# Round 59/100
# Average Loss: 0.6063, Average Accuracy: 78.93%
# Round 60/100
# Average Loss: 0.5915, Average Accuracy: 79.40%
# Round 61/100
# Average Loss: 0.5811, Average Accuracy: 79.61%
# Round 62/100
# Average Loss: 0.5689, Average Accuracy: 80.17%
# Round 63/100
# Average Loss: 0.5580, Average Accuracy: 80.72%
# Round 64/100
# Average Loss: 0.5473, Average Accuracy: 81.07%
# Round 65/100
# Average Loss: 0.5345, Average Accuracy: 81.62%
# Round 66/100
# Average Loss: 0.5244, Average Accuracy: 81.89%
# Round 67/100
# Average Loss: 0.5122, Average Accuracy: 82.17%
# Round 68/100
# Average Loss: 0.5002, Average Accuracy: 82.61%
# Round 69/100
# Average Loss: 0.4898, Average Accuracy: 83.01%
# Round 70/100
# Average Loss: 0.4787, Average Accuracy: 83.35%
# Round 71/100
# Average Loss: 0.4691, Average Accuracy: 83.70%
# Round 72/100
# Average Loss: 0.4542, Average Accuracy: 84.32%
# Round 73/100
# Average Loss: 0.4455, Average Accuracy: 84.59%
# Round 74/100
# Average Loss: 0.4342, Average Accuracy: 84.98%
# Round 75/100
# Average Loss: 0.4233, Average Accuracy: 85.37%
# Round 76/100
# Average Loss: 0.4138, Average Accuracy: 85.71%
# Round 77/100
# Average Loss: 0.4014, Average Accuracy: 86.03%
# Round 78/100
# Average Loss: 0.3888, Average Accuracy: 86.59%
# Round 79/100
# Average Loss: 0.3795, Average Accuracy: 86.93%
# Round 80/100
# Average Loss: 0.3697, Average Accuracy: 87.23%
# Round 81/100
# Average Loss: 0.3594, Average Accuracy: 87.52%
# Round 82/100
# Average Loss: 0.3478, Average Accuracy: 88.00%
# Round 83/100
# Average Loss: 0.3368, Average Accuracy: 88.43%
# Round 84/100
# Average Loss: 0.3239, Average Accuracy: 88.85%
# Round 85/100
# Average Loss: 0.3154, Average Accuracy: 89.28%
# Round 86/100
# Average Loss: 0.3042, Average Accuracy: 89.62%
# Round 87/100
# Average Loss: 0.2923, Average Accuracy: 89.95%
# Round 88/100
# Average Loss: 0.2838, Average Accuracy: 90.30%
# Round 89/100
# Average Loss: 0.2746, Average Accuracy: 90.54%
# Round 90/100
# Average Loss: 0.2622, Average Accuracy: 91.10%
# Round 91/100
# Average Loss: 0.2532, Average Accuracy: 91.47%
# Round 92/100
# Average Loss: 0.2430, Average Accuracy: 91.74%
# Round 93/100
# Average Loss: 0.2344, Average Accuracy: 92.08%
# Round 94/100
# Average Loss: 0.2238, Average Accuracy: 92.53%
# Round 95/100
# Average Loss: 0.2109, Average Accuracy: 93.04%
# Round 96/100
# Average Loss: 0.2110, Average Accuracy: 92.82%
# Round 97/100
# Average Loss: 0.2007, Average Accuracy: 93.38%
# Round 98/100
# Average Loss: 0.1866, Average Accuracy: 93.84%
# Round 99/100
# Average Loss: 0.1814, Average Accuracy: 94.06%
# Round 100/100
# Average Loss: 0.1715, Average Accuracy: 94.43%
# Test Accuracy: 74.45%
